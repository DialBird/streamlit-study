# %%
import openai

openai.api_key = ""

# %%
MODEL = "text-embedding-ada-002"

res = openai.Embedding.create(
    input=[
        "住宅ローン保証の最大手。独立系。M&Aに積極的。事業領域拡大目指しベンチャー投資も。新設住宅着工戸数厳しいが、新規保証実行が回復。商品説明会の開催増効いて、住宅ローンに積極的な地銀の利用率上昇。審査力生かし30代までの子育て世代を積極的に引き受けるキャンペーンも奏功。与信費用増吸収し営業増益。のれん益。",
        "宿泊施設向け予約管理システム開発・販売が主力。システム会社やサイト運営会社と連携積極的。コロナ影響緩和で旅行需要が回復。顧客宿泊施設の稼働率上昇し、つれて従量課金型の収入が好調。大半占める固定収入も好転。ただ、システム投資や人件費負担など重く、営業益はやや後退。微減配。コロナ影響緩和で旅行需要が回復。顧客宿泊施設の稼働率上昇し、つれて従量課金型の収入が好調。大半占める固定収入も好転。ただ、システム投資や人件費負担など重く、営業益はやや後退。微減配。",
        "居住用不動産を担保に事業性ローン提供。独特のノウハウで貸倒率低い。不動産賃貸事業も。顧客の資金ニーズ旺盛で貸付順調、解約も少なく営業貸付金残高拡大。前上期の延滞解消による収入剥落しても、平均貸付金利の低下止まり、利息収入伸長。資金調達費増吸収し営業増益。為替差益。顧客の資金需要や他金融機関の動向にらみつつ、案件に応じ徐々に貸付金利引き上げへ。米国で収益不動産取得に向け調査中。ドル調達も段階的に進める。",
        "アミューズメント向け等貸金業、不動産事業の2本柱経営。M&A仲介などコンサル事業展開も。短期貸付中心の貸金業が上向く。柱の不動産は前期取得5物件に新規2寄与し賃貸好伸。3物件売却で想定以上。後半、賃貸用保有の10物件を売却。ただ手数料負担増で営業益は前期並み。増配か。23年8月末賃貸用不動産38件、資産残高約478億円。23年度は遊戯施設関連10物件（約200億円）の取得目指す。協力企業と物流施設用不動産開発を推進。",
        "感染症抗体、ホルモンなどの体外検査用医薬品専業。インフルエンザから腎・肝機能など幅広い。新型コロナ遺伝子検査急減。抗原検査キットの好調、インフルエンザ単独検査や他の感染症検査の復調で補えず。大幅営業減益。24年12月期は新型コロナとインフルの同時検査キット引き続き堅調。小型迅速遺伝子解析装置の販売が上期末で累計5200台（期初5000台）に。判定時間の大幅短縮や複数項目同時検査可能な次世代製品の開発にも注力。",
        "独立系SI。ERP（統合業務ソフト）で中小・中堅向け首位、大企業向けも深耕。持分にOBC。顧客の投資意欲活発で、柱のSIは『オービック7』の導入が出足想定超、通期で快走。稼ぎ頭のサポートも2桁増維持。人件費増あっても営業益続伸。営業外に有価証券売却益計上、純益膨らむ。クラウドサービスの米国セキュリティ基準『SOC2 type2』取得。高い安全性を訴求。平均年収が1000万円突破。持分のオービーシステムが上場。",
        "プレステ用ゲームソフトの企画・開発主力、ロールプレイング系得意。アプリ等のライセンスも。期末の最新作ゲーム『イース10』が会社の想定超す貢献。重い開発費こなし営業増益。24年9月期は前期末配信の新作ゲームが通期で貢献。海外向けライセンス版が上乗せ。営業益着実増。最高純益。『イースX』は9月28日発売、中国語版、ハングル語版も同時発売。年初より放映のアニメ『閃の軌跡』や、『英雄伝説』のスマホ向けRPGゲームも配信へ。",
        "FAセンサーなど検出・計測制御機器大手。生産は国内工場軸に外注。持分にジャストシステム。上期は半導体や液晶向け軟調。ただ工場の自動化需要が続くうえ、前期の中国都市封鎖による悪影響なく、FAセンサーなど拡大。海外の人員増による費用増加こなす。為替差益続く。最高純益。海外売上高拡大に向け、人員採用を強化。現地でも高水準給与を支払うとともに自社商材の付加価値や機能の理解度を高める訓練徹底。優秀な営業員確保へ。",
        "物件掲載数首位の投資用不動産サイト『楽待』運営。加盟不動産からのサービス利用料が柱。24年7月期は収益柱の物件掲載サービスで加盟店数順調に積み上げ。過去に実施の新規取引先との値上げ効果継続。広告サービスも動画広告や高単価商品の受注注力。営業増益続く。連続増配も。不動産会社向けにチャットGPT活用した新機能提供。物件PR文、投資家問い合わせへの返信文を自動生成。『楽待』公式アプリが40万ダウンロード突破。",
        "原油・ガス開発生産国内最大手。政府が黄金株保有。豪州でLNG案件（イクシス）を操業。原油は市況下落。LNGは豪州イクシスで想定外の不具合発生、暖冬での販売量減も響く。円安でも前号比営業減益幅拡大。営業外に中東権益一部売却益等計上。24年12月期はイクシス生産復調で向上。ROIC重視で資本効率向上、株主還元積極化。12月29日まで上限8000万株・1000億円で自己株取得。プラントCO2回収推進で座礁資産化リスク低減。",
        "M&A仲介が柱。売り手企業は着手金など無料の完全成功報酬制。独自のマッチングシステム。連結開始。M&A仲介は新規採用アドバイザーの早期戦力化が寄与。成約単価は頭打ちだが件数上振れ。営業益急伸。24年9月期は手持ち案件豊富。増員効果で成約件数は8割超増加も。採用・教育費、人件費等のコスト増こなし連続大幅増益。自社システムにチャットGPTを導入する実験に着手。いずれ契約書締結まで活用検討。高年収武器に新卒採用拡大。",
        "高精度な位置情報配信サービス展開。測量分野など中心。日立産機システムと資本提携。好財務。主柱の位置情報配信サービス順調増。有力顧客のゼネコンなどへの提案営業強化が奏功。24年9月期は配信サービス着実。顧客の利用時間の長期化傾向続き、従量課金など伸長。マーケティング要員拡充による人件費増埋め、連続営業増益。物流や海洋、自動車分野などへの市場拡大を探る。6月末の契約件数は3月末から161件増えて8372件に。",
        "国内唯一の総合取引所グループ。傘下に東証、大阪取引所、東京商品取引所（TOCOM）。主力の現物株は6月の1日平均売買代金5.2兆円（前年同期比31.4%増）と活況。7月も4.5兆円と勢い維持。上場関連収益や情報関連収益も堅調。システム運用費重いが営業益好転。記念配剥落。東証初となるアクティブETFの上場を承認。9月に3社運用の6本が上場する。プライム上場企業に対し、25年までに女性取締役1人以上の選任を求める。",
        "ゲームソフト中堅のコーエーとテクモが09年経営統合。オンラインゲーム含め海外展開強化へ。スマホ向けは前期開始の『信長の野望 覇道』や複数新作貢献し好調推移。家庭用向けは『Fate』シリーズ新作などが寄与。開発費負担増こなし会社営業益上回る。営業外に有価証券売却益。『アトリエ』シリーズ新作を発表、アカツキゲームスと共同開発のスマホ向けタイトル。8月にベトナム開発拠点を設立、グローバルタイトルの開発支える。",
        "中古車オークション会場の運営で断トツ。中古車買い取り専門店の『ラビット』も。好財務。新車販売の回復を受け、中古車のオークション出品台数増え成約増。値上げも寄与し、手数料収入が拡大。プラントリサイクル事業は、大規模解体工事の受注件数が増えて成長続く。連続営業増益。今後の出品台数増に備え、評価基準や車両検査体制の確立に向けた研究開発など進める。出品票のデジタル化進め、入力工程の削減による業務効率化図る。",
        "企業の売掛債権保証で成長。リスクは再保証先に移転。地銀との業務提携積極化。伊藤忠系。企業倒産増加でニーズ強まり、保証残高順調増。平均保証料率が下げ止まり、後半から反転上昇。慎重な引き受けリスク判断と小口分散で、リスク移転費増抑制し利ザヤ拡大。人件費増こなし最高純益。IT活用で管理部門は自然減不補充、営業サポートへの業務振り替えも。北陸や東北など前期支店開設した地方で顧客訪問、商談時間増え契約獲得増に手応え。",
        "人工ダイヤの原料の種結晶を製造販売。人工宝石用中心。工具や半導体用も。産総研の特許利用。主柱の人工ダイヤ用種結晶は主顧客の海外の人工宝石メーカー向け大口輸出を4〜6月に停止。7月から順次再開だが、出足の低迷カバーしきれず。人件費や償却負担増も重荷。一転、営業減益。輸出貿易管理令一部改正に伴い種結晶等の1件100万円超の輸出を自主的に一時保留、7月から同案件は順次申請・許可経て輸出。パワー半導体用発売。",
        "独立系M&A仲介会社。事業承継案件が得意で調剤薬局に強い顧客基盤。16年にレコフを買収。案件の大型化で収益性向上。が、成約件数は横ばい。人件費増やオフィス移転重い。営業益小幅減。初配。24年9月期はコンサルタントの採用を加速し、成約件数が上向く。大型案件比率も一段高まる。人件費重いが、最高純益圏。増配も。コンサルタント数は24年9月末で234人（23年6月末は173人）に。中国・四国地方でリアルセミナー積極化。",
        "ソフトクリエイトHD傘下。ワークフローソフト専業。パッケージと中小向けにクラウド展開。企業DXやテレワーク定着でワークフローの導入拡大。中堅・中小向けはクラウドへの移行進む。前半低調な大企業向けは新バージョン投入で後半回復。人件費の増加こなし営業益続伸。連続増配。大企業向け製品で13年ぶり新バージョン投入、ワークフロー統合化を訴求。長期保有株主優待制度新設、連続保有2年以上の株主にクオカードを追加贈呈。",
        "『ATOK』等や法人業務システムなどを展開。通信教育『スマイルゼミ』が柱。キーエンス系。法人向けの営業支援やDB製品が好調。ただ、収益柱の『スマイルゼミ』は会員数増が頭打ち。高校生コースや米国の立ち上げ費用も重い。前号の営業増益予想から一転減益に。配当余力大きく増配濃厚。年間で最も金額が膨らむ6月末の前受収益は132億円（前年同期比6.5%減）に。スマイルゼミの国内は販促を継続、米国事業は認知度向上に注力。",
        "23年度石炭事業撤退で事業投資会社に転換。飲料ストロー等ニッチ企業をM&Aで取り込み。生活関連堅調。前期買収のレシート原紙子会社貢献。前期市況高騰の石炭事業は出足想定超だが下期に価格下落。炭鉱終掘で生産、販売量も減る。半導体向け電子部品の特需剥落。増額ながら営業益反落。三菱製紙孫会社の感熱紙加工販売事業譲受。感熱レジロール需要旺盛なコンビニ市場参入へ。8月計量装置製造会社買収。今期100億円投じ事業転換急ぐ。",
        "投資ファンドを運用。投資対象は国内外の企業やREIT、実物資産。21年7月に持株会社化。ファンド管理報酬はバイアウト2号の組成で伸長。下期に既存ファンドの成功報酬が順調増。中国のオフィスビルなど自己投資横ばい。営業益快走。配当性向は5年平均純益30%程度メドで増配。24年12月期はファンド拡大で管理報酬一段増。バイアウト2号は9月中に総額400億円以上で組成完了見込み。航空機ファンドに注力し資産投資需要取り込む。",
        "投資事業が収益柱で保有メルカリ株の売却益毎期計上。プログラミング教育、ネット広告等も。第1四半期にメルカリ株売却。教育関連はヤフーとの提携事業が堅調だが、注力中の生成AIコースの広告費が重い。人材事業も先行投資かさむ。のれんもあり営業減益。権利譲渡特益ない。記念配。競合増で苦戦の教育関連は、ヤフーとの提携事業と生成AIコースで立て直し図る。生成AI活用の組織横断部隊を発足、生産性向上やサービス実装推進。",
        "通称OBC。中小企業向け業務パッケージソフト『奉行シリーズ』で著名。オービックが大株主。柱の奉行シリーズはインボイス制度対応や旺盛なDX需要で出足から想定超。クラウド版の拡大がオンプレの縮小を上回る。広告費積み増しやシステム刷新費用など吸収。前号より営業増益幅やや拡大。顧客管理システムを刷新。製品軸から顧客軸に転換し、クロスセルを強化。インボイス・電子帳簿保存法対応のクラウド製品を投入、広告など販促を積極化。",
        "在宅医療担う訪問看護師へ記録書類作成等支援ツールをクラウド提供、事務作業の業務代行も。柱のクラウドサービスは電子カルテ・レセプトとも訪問看護ステーション契約数が順調増。事務管理代行も伸長。広告費増や本社移転費こなし営業益続伸。24年12月期もクラウド軸に新規契約獲得続く。電子カルテ情報活用したデータビジネス確立目指し、同分野の調査・研究に重点投資。契約数拡大踏まえ既存顧客対応や事務管理代行に当たる人員体制強化。",
        "日本株主軸の独立系投資顧問。香港、韓国に資産運用子会社。不動産、環境、復興など投資多角化。資産運用残高が好調な市況を背景に順調に伸び、残高報酬は手堅く積み上がる。成功報酬も着実。再エネファンドも堅調。コロナ明けの人件費・旅費交通費増をこなし営業益の改善続く。有証売却特益。苫小牧市の再エネ水素サプライチェーン実証事業を子会社が開始。新エネビジネス模索。香港、韓国の運用チームが頻繁に日本訪問、方針のすりあわせを密に。",
        "ロシュ傘下で成長続ける異色の医薬品大手。抗体・バイオで先行、抗がん剤、骨・関節領域に強い。抗悪性腫瘍薬『ポライビー』など新製品が牽引。だがコロナ向け『ロナプリーブ』大幅減、特許訴訟受取和解金919億円剥落し営業益大幅反落。増配。24年12月期は『ロナプリーブ』減を新製品が補う。自社創製品で独自技術『スイッチ抗体』用いたがん治療薬『ROSE12』が6月に第1相試験入り。次世代がん薬候補の中分子薬の1つが新たに前臨床入り。",
        "ネットセキュリティ専業。安全サイトのみ接続できるフィルタ技術に強み。コンサル事業育成。コンサルの増員や新製品の投入の負担で出足は軟調。ただ、通期はセキュリティ対策強化を進める企業向けや、受注残の豊富な学校向けが収益を牽引。クラウド費用の膨張を吸収し、営業連続増益。10月にファイル転送サービス『f‐フィルター』を投入。製品群を拡充し、国産でのゼロトラスト運用を訴求。12月末まで20万株、10億円を上限に自己株買い。",
        "ビッグデータの各種解析ツールや人工知能（AI）を使った業務支援ツールを開発・提供。AIチャットボットが導入数増加し好調。SNS分析の『ソーシャルインサイト』も販促用の需要着実に取り込む。新製品開発費や広告宣伝費増こなし営業増益続く。前期の有証評価特損なくなる。記事生成AIの提供を開始。GPTと連携しキーワード入力のみで記事の作成が可能。チャットGPT搭載のLINEボット作成サービスを無料提供。",
        "士業（公認会計士、弁護士等）と一般事業会社の管理部門に特化の人材紹介業。関連メディアも。稼ぎ頭の人材紹介は登録者数・求人数ともに伸長、マッチング精度向上で増勢。ダイレクトリクルーティングも提携エージェント数が積み上がり拡大続く。広告費や人件費が膨らんでも営業益続伸。人材紹介の登録者・求人獲得に向け、マーケ費投入に加えインサイドセールスの体制拡充。メディア関連ではリアル含めたイベント再強化し収益機会増やす。",
    ], engine=MODEL
)

# %%
MODEL = "text-embedding-ada-002"

res = openai.Embedding.create(
    input=[
        "優秀なIT企業はどこですか？",
    ], engine=MODEL
)

# %%
import json

with open('data.txt', 'w', encoding='utf-8') as file:
    dict1 = res['data'][0]['embedding']
    json.dump(dict1, file, indent = 2)

# %%
len(res['data'])
# Out:
# 30

# %%
embeds = [record['embedding'] for record in res['data']]
embeds[0]

# %%
import pinecone

pinecone.init(api_key="", environment="")
index = pinecone.Index("rerankers")

# %%
index.upsert(
    vectors=[
        { 'id': "7164", 'values': embeds[0], 'metadata': {'PER': 10.97 }},
        { 'id': "2477", 'values': embeds[1], 'metadata': {'PER': 15.53}},
        { 'id': "8772", 'values': embeds[2], 'metadata': {'PER': 7.21}},
        { 'id': "6625", 'values': embeds[3], 'metadata': {'PER': 10.96}},
        { 'id': "4595", 'values': embeds[4], 'metadata': {'PER': 9.68}},
        { 'id': "4684", 'values': embeds[5], 'metadata': {'PER': 38.5}},
        { 'id': "3723", 'values': embeds[6], 'metadata': {'PER': 12.23}},
        { 'id': "6861", 'values': embeds[7], 'metadata': {'PER': 35.6}},
        { 'id': "6037", 'values': embeds[8], 'metadata': {'PER': 15.2}},
        { 'id': "1605", 'values': embeds[9], 'metadata': {'PER': 9.1}},
        { 'id': "9552", 'values': embeds[10], 'metadata': {'PER': 52.3}},
        { 'id': "5570", 'values': embeds[11], 'metadata': {'PER': 26.64}},
        { 'id': "8697", 'values': embeds[12], 'metadata': {'PER': 28.3}},
        { 'id': "3635", 'values': embeds[13], 'metadata': {'PER': 19.8}},
        { 'id': "4732", 'values': embeds[14], 'metadata': {'PER': 21.5}},
        { 'id': "8771", 'values': embeds[15], 'metadata': {'PER': 25.4}},
        { 'id': "7794", 'values': embeds[16], 'metadata': {'PER': 29.7}},
        { 'id': "6080", 'values': embeds[17], 'metadata': {'PER': 13.3}},
        { 'id': "3969", 'values': embeds[18], 'metadata': {'PER': 12.8}},
        { 'id': "4686", 'values': embeds[19], 'metadata': {'PER': 13.5}},
        { 'id': "1518", 'values': embeds[20], 'metadata': {'PER': 2.97}},
        { 'id': "7347", 'values': embeds[21], 'metadata': {'PER': 9.69}},
        { 'id': "2497", 'values': embeds[22], 'metadata': {'PER': 11.1}},
        { 'id': "4733", 'values': embeds[23], 'metadata': {'PER': 38.9}},
        { 'id': "5038", 'values': embeds[24], 'metadata': {'PER': 36.6}},
        { 'id': "8739", 'values': embeds[25], 'metadata': {'PER': 12.1}},
        { 'id': "4519", 'values': embeds[26], 'metadata': {'PER': 25.0}},
        { 'id': "2326", 'values': embeds[27], 'metadata': {'PER': 16.4}},
        { 'id': "3984", 'values': embeds[28], 'metadata': {'PER': 22.7}},
        { 'id': "6539", 'values': embeds[29], 'metadata': {'PER': 20.3}},
    ],
    namespace='test'
)
# Out:
# {'upserted_count': 30}

# %%
query = "優れたIT企業を挙げて"

xq = openai.Embedding.create(input=query, engine=MODEL)['data'][0]['embedding']

# %%
res = index.query([xq], top_k=5, include_metadata=True, namespace='test')

# %%
for match in res['matches']:
    print(f"{match['score']:.2f}: {match['metadata']['text']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/taniguchitakashiryou/study/LLM/streamlit-study/embed.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/Users/taniguchitakashiryou/study/LLM/streamlit-study/embed.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> for match in res['matches']:
# ----> <a href='vscode-notebook-cell:/Users/taniguchitakashiryou/study/LLM/streamlit-study/embed.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     print(f"{match['score']:.2f}: {match['metadata']['text']}")
#
# KeyError: 'text'

# %%
res['matches']
# Out:
# [{'id': '3969', 'metadata': {'PER': 12.8}, 'score': 0.836833596, 'values': []},
#  {'id': '4684', 'metadata': {'PER': 38.5}, 'score': 0.827556968, 'values': []},
#  {'id': '2326', 'metadata': {'PER': 16.4}, 'score': 0.824252784, 'values': []},
#  {'id': '4733', 'metadata': {'PER': 38.9}, 'score': 0.821893811, 'values': []},
#  {'id': '8771', 'metadata': {'PER': 25.4}, 'score': 0.820399821, 'values': []}]
